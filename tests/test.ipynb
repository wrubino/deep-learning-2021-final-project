# %%
from toolbox.initialization import *

# %%
tests.test_all()
# Out:
#                 Variant    R  L_e_original  L_e_rubino  L_original  L_rubino
# 0  zoom_augmented_f1_c1 0.81     80,046.03        0.03       -0.01     -0.81
# 1  zoom_augmented_f1_c4 0.70    154,911.83        1.54        0.85     -0.66
# 2  zoom_augmented_f4_c1 0.66    140,987.92        6.16        0.75     -0.53
# 3  zoom_augmented_f4_c4 0.60    205,920.37        7.05        1.46     -0.46
# 4                babble 0.71     81,953.89        0.84        0.11     -0.69
# 5             distorted 0.52    130,384.88        0.79        0.78     -0.50
# 6                 music 0.61     93,008.36        0.94        0.32     -0.59
# 7                    tv 0.52    119,213.03        0.05        0.68     -0.52
# 8                  zoom 0.79     54,616.07        0.05       -0.25     -0.79
# 9                 clean 1.00          0.00        0.00       -1.00     -1.00
